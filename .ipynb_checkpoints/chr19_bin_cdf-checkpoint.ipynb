# %%
data <- read.csv("A_clusterdf")
data
# Out:
#       X     bin_ID         high      medium      low
# 1      1    chr19_10000700   0.00000  91.7647059  8.235294
# 2      2    chr19_10001300  66.40625   3.9062500 29.687500
# 3      3    chr19_10005900  82.26950   2.1276596 15.602837
# 4      4    chr19_10009400  73.95833   4.6875000 21.354167
# 5      5    chr19_10010400  47.58621  12.4137931 40.000000
# 6      6    chr19_10010800  85.18519   3.7037037 11.111111
# 7      7    chr19_10012700  46.60194   9.7087379 43.689320
# 8      8    chr19_10015200  56.20915   7.1895425 36.601307
# 9      9    chr19_10015300  59.01639   0.0000000 40.983607
# 10    10    chr19_10016200  77.31959   0.0000000 22.680412
# 11    11    chr19_10016300   0.00000  14.2857143 85.714286
# 12    12    chr19_10017400  80.92105   0.0000000 19.078947
# 13    13    chr19_10018000   0.00000  93.3333333  6.666667
# 14    14    chr19_10018300   0.00000 100.0000000  0.000000
# 15    15    chr19_10018500   0.00000 100.0000000  0.000000
# ...

# %%
pos <- data$bin_ID

s <- function(x){
    as.numeric(strsplit(as.character(x), "_")[[1]][2])
}
new_pos <- sapply(pos, s)
new_pos
# Out:
#     [1] 10000700 10001300 10005900 10009400 10010400 10010800 10012700 10015200
#     [9] 10015300 10016200 10016300 10017400 10018000 10018300 10018500 10018600
#    [17] 10020400 10020600 10024400 10027500 10027600 10027700 10028500 10029000
#    [25] 10031900 10032400 10032500 10033800 10034700 10035400 10035800 10038700
#    [33] 10041000 10041200 10041900 10042600 10051700 10051800 10052300 10052900
#    [41] 10053900 10056100 10056200 10056300 10057100 10062400 10063100 10066600
#    [49] 10071500 10074200 10076300 10076600 10076700 10077700 10077800 10080600
#    [57] 10082000 10085700 10087600 10088600 10089500 10090000 10090600 10090700
#    [65] 10090800 10091100 10092100 10092800 10093000 10093500 10095100 10095800
#    [73] 10096100 10098900 10099200 10103200 10103600 10104400 10104500 10107000
#    [81] 10112600 10115200 10118100 10119800 10123500 10129100 10132700 10133000
#    [89] 10133400 10134400 10134600 10136000 10137700 10138900 10139700 10141000
# ...

# %%
plot(ecdf(new_pos))
# Out:
# Plot with title “ecdf(new_pos)”
